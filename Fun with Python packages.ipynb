# %%
# !pip install emoji
# Out:
# ...
#      -------------------------------------- 608.4/608.4 kB 1.8 MB/s eta 0:00:00
# ...

# %%
import emoji

# %%
emoji.emojize("I'm having fun with Python :red_heart:")
# Out:
# "I'm having fun with Python ❤️"

# %%
# !pip install tqdm

# %%
from tqdm import tqdm
from time import sleep

# %%
for _ in tqdm(range(1000)):
    sleep(0.1)
# Out:
# 100%|██████████| 1000/1000 [01:49<00:00,  9.16it/s]
